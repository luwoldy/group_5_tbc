# %%
import pandas as pd
import scipy.stats as stats
import numpy as np
from matplotlib import pyplot as plt
from scipy.stats import linregress
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy.stats import norm

# %%
price_csv = pd.read_csv("Files/master_df.csv")

# %%
price_csv.head()
# Out:
#    Unnamed: 0        Date Company  Num_aticles  Neg_news_percent  \
# 0           0  2018-12-20  Amazon          100               -41
# 1           1  2018-12-21  Amazon          100               -32
# 2           2  2018-12-24  Amazon          100               -34
# 3           3  2018-12-26  Amazon          100               -48
# 4           4  2018-12-27  Amazon          100               -46
#
#    Pos_news_percent  Neut_article_percent  COD_Price  Avr_sentiment  Positive
# 0                59                     0     -2.523       2.910099      True
# 1                68                     0     -3.890       3.902253      True
# 2                62                     4     -2.587       2.418167      True
# 3                52                     0      7.042       2.154726      True
# 4                53                     1     -0.649      -0.081374     False

# %% [markdown]
# # TTest

# %%
x = list(price_csv["Avr_sentiment"])
y = list(price_csv["COD_Price"])
stats.ttest_ind(x,y, axis=0, equal_var=False )
# Out:
# Ttest_indResult(statistic=6.437936481969912, pvalue=1.054037304398875e-09)

# %% [markdown]
# # Regression Analysis(Scipy)

# %%
(slope, intercept,rvalue,pvalue, stderr)=linregress(x,y)
fit = slope * price_csv["Avr_sentiment"] + intercept
reg_df= pd.DataFrame({"Slope": [slope], "Intercept": [intercept], "Rvalue": [rvalue], "Pvalue": [pvalue], "StdErr": [stderr]})

# %%
reg_df.head()
# Out:
#       Slope  Intercept    Rvalue    Pvalue    StdErr
# 0 -0.024088   0.465895 -0.033013  0.744369  0.073665

# %% [markdown]
# # Regression Analysis(StatModels)

# %%
avr_sent = list(price_csv["Avr_sentiment"])
price_ch = list(price_csv["COD_Price"])
mod = smf.ols(formula='price_ch ~ avr_sent', data=price_csv)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               price_ch   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.009
# Method:                 Least Squares   F-statistic:                    0.1069
# Date:                Mon, 21 Jan 2019   Prob (F-statistic):              0.744
# Time:                        14:32:21   Log-Likelihood:                -235.85
# No. Observations:                 100   AIC:                             475.7
# Df Residuals:                      98   BIC:                             480.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4659      0.350      1.332      0.186      -0.228       1.160
# avr_sent      -0.0241      0.074     -0.327      0.744      -0.170       0.122
# ==============================================================================
# Omnibus:                       14.157   Durbin-Watson:                   2.194
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               51.919
# Skew:                           0.079   Prob(JB):                     5.32e-12
# Kurtosis:                       6.526   Cond. No.                         6.56
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Graphical Regression

# %%
# %matplotlib notebook
fig, ax = plt.subplots()
#fig.sptitle("afasfasf", fontsize=16, fontweight="bold")
ax.set_ylim(-10,10)
ax.set_xlim(-10,10)

ax.plot(x,y, linewidth=0, marker="o")
ax.plot(x, fit, linewidth=2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Normal Distribution Test

# %%
# %matplotlib notebook
# Generate some data for this demonstration.
data =y

# Fit a normal distribution to the data:
mu, std = norm.fit(data)

# Plot the histogram.
plt.hist(data, bins=25, density=True, alpha=0.6, color='g')

# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit results: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
